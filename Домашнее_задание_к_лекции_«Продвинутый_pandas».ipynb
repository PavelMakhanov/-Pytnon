# %%
import pandas as pd

# %% [markdown]
# ##Задание 1
#
# Для датафрейма log из материалов занятия создайте столбец source_type по следующим правилам:
#
# -если источник traffic_source равен yandex или google, то в source_type ставится organic
#
# -для источников paid и email из России - ставим ad
#
# -для источников paid и email не из России - ставим other
#
# -все остальные варианты берем из traffic_source без изменений

# %%
log = pd.read_csv('visit_log.csv', sep = ';')

# %%
log.head()
# Out:
#     timestamp    visit_id                                 url  region  \
# 0  1549980692  e3b0c44298  https://host.ru/3c19b4ef7371864fa3  Russia
# 1  1549980704  6e340b9cff  https://host.ru/c8d9213a31839f9a3a  Russia
# 2  1549980715  96a296d224  https://host.ru/b8b58337d272ee7b15  Russia
# 3  1549980725  709e80c884  https://host.ru/b8b58337d272ee7b15  Russia
# 4  1549980736  df3f619804  https://host.ru/b8b58337d272ee7b15  Russia
#
#       user_id traffic_source
# 0  b1613cc09f         yandex
# 1  4c3ec14bee         direct
# 2  a8c40697fb         yandex
# 3  521ac1d6a0         yandex
# 4  d7323c571c         yandex

# %% [markdown]
# **С помощью метода loc фильтруем данные и присваиваем новому столбцу 'source_type' соответствующие значения**

# %%
log.loc[log['traffic_source'].isin(['yandex','google']), 'source_type'] = 'organic'
log.loc[(log['traffic_source'].isin(['paid','email'])) & (log['region'] == 'Russia') , 'source_type'] = 'ad'
log.loc[(log['traffic_source'].isin(['paid','email'])) & (log['region'] != 'Russia') , 'source_type'] = 'other'
log.loc[log['source_type'].isnull() , 'source_type'] = log['traffic_source']

# %%
log.head()
# Out:
#     timestamp    visit_id                                 url  region  \
# 0  1549980692  e3b0c44298  https://host.ru/3c19b4ef7371864fa3  Russia
# 1  1549980704  6e340b9cff  https://host.ru/c8d9213a31839f9a3a  Russia
# 2  1549980715  96a296d224  https://host.ru/b8b58337d272ee7b15  Russia
# 3  1549980725  709e80c884  https://host.ru/b8b58337d272ee7b15  Russia
# 4  1549980736  df3f619804  https://host.ru/b8b58337d272ee7b15  Russia
#
#       user_id traffic_source source_type
# 0  b1613cc09f         yandex     organic
# 1  4c3ec14bee         direct      direct
# 2  a8c40697fb         yandex     organic
# 3  521ac1d6a0         yandex     organic
# 4  d7323c571c         yandex     organic

# %% [markdown]
# ##Задание 2
#
# В файле URLs.txt содержатся url страниц новостного сайта. Вам необходимо отфильтровать его по адресам страниц с текстами новостей. Известно, что шаблон страницы новостей имеет внутри url следующую конструкцию: /, затем 8 цифр, затем дефис.
#
# Выполните следующие действия:
#
# -Прочитайте содержимое файла с датафрейм
#
# -Отфильтруйте страницы с текстом новостей, используя метод str.contains и регулярное выражение в соответствии с заданным шаблоном

# %%
urls = pd.read_table('URLs.txt')

# %%
urls.head()
# Out:
#                                                  url
# 0                                            /world/
# 1                                           /latest/
# 2                                      /?updated=top
# 3  /politics/36188461-s-marta-zhizn-rossiyan-susc...
# 4  /world/36007585-tramp-pridumal-kak-reshit-ukra...

# %% [markdown]
# **Импортируем библиотеку ругулярных выражений и создаем шаблон**

# %%
import re

# %%
pattern = r'\/\d{8}\-'

# %% [markdown]
# **Фильтруем данные файла**

# %%
urls[urls['url'].str.contains(pattern)]
# Out:
#                                                   url
# 3   /politics/36188461-s-marta-zhizn-rossiyan-susc...
# 4   /world/36007585-tramp-pridumal-kak-reshit-ukra...
# 5   /science/36157853-nasa-sobiraet-ekstrennuyu-pr...
# 6   /video/36001498-poyavilis-pervye-podrobnosti-g...
# 7   /world/36007585-tramp-pridumal-kak-reshit-ukra...
# ..                                                ...
# 88  /cis/35984145-kreml-prokommentiroval-soobschen...
# 89  /video/36071019-olimpiyskie-obekty-rio-prevrat...
# 90  /science/36151301-nazvano-posledstvie-zloupotr...
# 91  /incidents/36027330-vospitatelnitsu-zatravili-...
# 92  /world/36103095-dominikanskih-zhurnalistov-ubi...
#
# [84 rows x 1 columns]

# %% [markdown]
# ##Задание 3
#
# Используйте файл с оценками фильмов ml-latest-small/ratings.csv.
#
# Посчитайте среднее время жизни пользователей, которые выставили более 100 оценок.
#
# Под временем жизни понимается разница между максимальным и минимальным значением столбца timestamp для данного значения userId.

# %%
ratings = pd.read_csv('ratings.csv')

# %%
ratings.head()
# Out:
#    userId  movieId  rating   timestamp
# 0       1       31     2.5  1260759144
# 1       1     1029     3.0  1260759179
# 2       1     1061     3.0  1260759182
# 3       1     1129     2.0  1260759185
# 4       1     1172     4.0  1260759205

# %% [markdown]
# **Добавим столбец с количеством оценок для каждого пользователя**

# %%
ratings['count_ratings'] = ratings['userId'].map(ratings.groupby('userId')['rating'].count())

# %%
ratings.head()
# Out:
#    userId  movieId  rating   timestamp  count_ratings
# 0       1       31     2.5  1260759144             20
# 1       1     1029     3.0  1260759179             20
# 2       1     1061     3.0  1260759182             20
# 3       1     1129     2.0  1260759185             20
# 4       1     1172     4.0  1260759205             20

# %% [markdown]
# **Отфильтруем полученный датафрейм и оставим только пользователей с количеством оценок больше 100**

# %%
ratings_100 = ratings.loc[ratings['count_ratings'] > 100]

# %%
ratings_100.head()
# Out:
#      userId  movieId  rating  timestamp  count_ratings
# 147       4       10     4.0  949810645            204
# 148       4       34     5.0  949919556            204
# 149       4      112     5.0  949810582            204
# 150       4      141     5.0  949919681            204
# 151       4      153     4.0  949811346            204

# %% [markdown]
# **Расчитаем минимальное и максимальное значения столбца 'timestamp' и добавим соответствующие стольбцы в датафрейм**

# %%
ratings_100['min_timestamp'] = ratings['userId'].map(ratings.groupby('userId')['timestamp'].min())
# Out:
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   """Entry point for launching an IPython kernel.

# %%
ratings_100.head()
# Out:
#      userId  movieId  rating  timestamp  count_ratings  min_timestamp
# 147       4       10     4.0  949810645            204      949778714
# 148       4       34     5.0  949919556            204      949778714
# 149       4      112     5.0  949810582            204      949778714
# 150       4      141     5.0  949919681            204      949778714
# 151       4      153     4.0  949811346            204      949778714

# %%
ratings_100['max_timestamp'] = ratings['userId'].map(ratings.groupby('userId')['timestamp'].max())
# Out:
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   """Entry point for launching an IPython kernel.

# %%
ratings_100.head()
# Out:
#      userId  movieId  rating  timestamp  count_ratings  min_timestamp  \
# 147       4       10     4.0  949810645            204      949778714
# 148       4       34     5.0  949919556            204      949778714
# 149       4      112     5.0  949810582            204      949778714
# 150       4      141     5.0  949919681            204      949778714
# 151       4      153     4.0  949811346            204      949778714
#
#      max_timestamp
# 147      949982274
# 148      949982274
# 149      949982274
# 150      949982274
# 151      949982274

# %% [markdown]
# **Рассчитаем время жизни каждого клиента**

# %%
ratings_100['Lifetime_Value']= ratings_100['max_timestamp'] - ratings_100['min_timestamp']
# Out:
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   """Entry point for launching an IPython kernel.

# %%
ratings_100.head()
# Out:
#      userId  movieId  rating  timestamp  count_ratings  min_timestamp  \
# 147       4       10     4.0  949810645            204      949778714
# 148       4       34     5.0  949919556            204      949778714
# 149       4      112     5.0  949810582            204      949778714
# 150       4      141     5.0  949919681            204      949778714
# 151       4      153     4.0  949811346            204      949778714
#
#      max_timestamp  Lifetime_Value
# 147      949982274          203560
# 148      949982274          203560
# 149      949982274          203560
# 150      949982274          203560
# 151      949982274          203560

# %% [markdown]
# **Приведем столбец 'Lifetime_Value', который показывает время жизни клиента, в более привычный формат,в формат дней, часов,минут и отобразим эти данные в новом столбце 'LTV'**

# %%
ratings_100['LTV'] = pd.to_timedelta(ratings_100['Lifetime_Value'] * 10**9)
# Out:
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   """Entry point for launching an IPython kernel.

# %%
ratings_100.head()
# Out:
#      userId  movieId  rating  timestamp  count_ratings  min_timestamp  \
# 147       4       10     4.0  949810645            204      949778714
# 148       4       34     5.0  949919556            204      949778714
# 149       4      112     5.0  949810582            204      949778714
# 150       4      141     5.0  949919681            204      949778714
# 151       4      153     4.0  949811346            204      949778714
#
#      max_timestamp  Lifetime_Value             LTV
# 147      949982274          203560 2 days 08:32:40
# 148      949982274          203560 2 days 08:32:40
# 149      949982274          203560 2 days 08:32:40
# 150      949982274          203560 2 days 08:32:40
# 151      949982274          203560 2 days 08:32:40

# %% [markdown]
# **Оставим только столбцы с времеменем жизни пользователей, удалим дубликаты и рассчитаем среднее время жизни всех пользователей**

# %%
user_LTV = ratings_100[['userId', 'Lifetime_Value','LTV']]

# %%
user_LTV.head()
# Out:
#      userId  Lifetime_Value             LTV
# 147       4          203560 2 days 08:32:40
# 148       4          203560 2 days 08:32:40
# 149       4          203560 2 days 08:32:40
# 150       4          203560 2 days 08:32:40
# 151       4          203560 2 days 08:32:40

# %%
user_LTV = user_LTV.drop_duplicates(subset=['userId', 'Lifetime_Value','LTV'], keep='first')

# %%
user_LTV.head()
# Out:
#       userId  Lifetime_Value                LTV
# 147        4          203560    2 days 08:32:40
# 583        8           85187    0 days 23:39:47
# 962       15       471393496 5455 days 22:38:16
# 2691      17            8053    0 days 02:14:13
# 3105      19            5282    0 days 01:28:02

# %%
user_LTV['Lifetime_Value'].mean()
# Out:
# 40080507.4496124

# %%
user_LTV['LTV'].mean()
# Out:
# Timedelta('463 days 21:28:27.449612408')

# %% [markdown]
# ##Задание 4
#
# Дана статистика услуг перевозок клиентов компании по типам (см. файл “Python_13_join.ipynb” в разделе Материалы для лекции «Продвинутый pandas» ---- Ноутбуки к лекции «Продвинутый pandas»).
#
# Необходимо сформировать две таблицы:
#
# -таблицу с тремя типами выручки для каждого client_id без указания адреса клиента
#
# -аналогичную таблицу по типам выручки с указанием адреса клиента

# %% [markdown]
# ### К домашнему заданию
# Дана статистика услуг перевозок клиентов компании по типам:
# - rzd - железнодорожные перевозки
# - auto - автомобильные перевозки
# - air - воздушные перевозки
# - client_base - адреса клиентов

# %%
rzd = pd.DataFrame(
    {
        'client_id': [111, 112, 113, 114, 115],
        'rzd_revenue': [1093, 2810, 10283, 5774, 981]
    }
)
rzd
# Out:
#    client_id  rzd_revenue
# 0        111         1093
# 1        112         2810
# 2        113        10283
# 3        114         5774
# 4        115          981

# %%
auto = pd.DataFrame(
    {
        'client_id': [113, 114, 115, 116, 117],
        'auto_revenue': [57483, 83, 912, 4834, 98]
    }
)
auto
# Out:
#    client_id  auto_revenue
# 0        113         57483
# 1        114            83
# 2        115           912
# 3        116          4834
# 4        117            98

# %%
air = pd.DataFrame(
    {
        'client_id': [115, 116, 117, 118],
        'air_revenue': [81, 4, 13, 173]
    }
)
air
# Out:
#    client_id  air_revenue
# 0        115           81
# 1        116            4
# 2        117           13
# 3        118          173

# %%
client_base = pd.DataFrame(
    {
        'client_id': [111, 112, 113, 114, 115, 116, 117, 118],
        'address': ['Комсомольская 4', 'Энтузиастов 8а', 'Левобережная 1а', 'Мира 14', 'ЗЖБИиДК 1', 
                    'Строителей 18', 'Панфиловская 33', 'Мастеркова 4']
    }
)
client_base
# Out:
#    client_id          address
# 0        111  Комсомольская 4
# 1        112   Энтузиастов 8а
# 2        113  Левобережная 1а
# 3        114          Мира 14
# 4        115        ЗЖБИиДК 1
# 5        116    Строителей 18
# 6        117  Панфиловская 33
# 7        118     Мастеркова 4

# %% [markdown]
# **Создаем таблицу с тремя типами выручки для каждого client_id без указания адреса клиента с помощью соединения таблиц**

# %%
df = rzd.merge(auto , on = 'client_id' , how = 'outer')

# %%
user_type_revenue = df.merge(air , on = 'client_id' , how = 'outer' )

# %%
user_type_revenue
# Out:
#    client_id  rzd_revenue  auto_revenue  air_revenue_x  air_revenue_y
# 0        111       1093.0           NaN            NaN            NaN
# 1        112       2810.0           NaN            NaN            NaN
# 2        113      10283.0       57483.0            NaN            NaN
# 3        114       5774.0          83.0            NaN            NaN
# 4        115        981.0         912.0           81.0           81.0
# 5        116          NaN        4834.0            4.0            4.0
# 6        117          NaN          98.0           13.0           13.0
# 7        118          NaN           NaN          173.0          173.0

# %% [markdown]
# **Создаем аналогичную таблицу по типам выручки с указанием адреса клиента**

# %%
user_address = user_type_revenue.merge(client_base, on = 'client_id', how = 'left')

# %%
user_address
# Out:
#    client_id  rzd_revenue  auto_revenue  air_revenue_x  air_revenue_y  \
# 0        111       1093.0           NaN            NaN            NaN
# 1        112       2810.0           NaN            NaN            NaN
# 2        113      10283.0       57483.0            NaN            NaN
# 3        114       5774.0          83.0            NaN            NaN
# 4        115        981.0         912.0           81.0           81.0
# 5        116          NaN        4834.0            4.0            4.0
# 6        117          NaN          98.0           13.0           13.0
# 7        118          NaN           NaN          173.0          173.0
#
#            address
# 0  Комсомольская 4
# 1   Энтузиастов 8а
# 2  Левобережная 1а
# 3          Мира 14
# 4        ЗЖБИиДК 1
# 5    Строителей 18
# 6  Панфиловская 33
# 7     Мастеркова 4
